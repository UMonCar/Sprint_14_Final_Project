# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
# # Proyecto Final: Telecomunicaciones: identificar operadores ineficaces
#
# https://github.com/UMonCar/Sprint_14_Final_Project
#
# Aquí tienes una recomendación para el libro *Git for Teams* y algunos consejos para mejorar la colaboración en tu repositorio:
#
# ---
#
# <div class="alert alert-block alert-info">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# **Recomendación de Lectura**: Te sugiero revisar *Git for Teams* de Emma Jane Hogbin Westby. Este libro se enfoca en el uso colaborativo de Git, cubriendo aspectos como estrategias de ramas, revisiones de código y la implementación de flujos de trabajo eficientes para equipos. Es ideal para desarrollar habilidades en la gestión de versiones en proyectos colaborativos y para adoptar prácticas que optimicen el trabajo en equipo y el control de versiones.
#
# **Consejos para el Repositorio**:
# 1. **Estructura del README**:
#    - **Objetivo del Proyecto**: Describe brevemente el propósito del proyecto y el problema que aborda.
#    - **Instrucciones para Clonar y Configurar**: Añade los pasos necesarios para clonar el proyecto y ejecutar una configuración básica, incluyendo dependencias.
#    - **Estructura del Proyecto**: Incluye una lista breve de las carpetas principales, como `SQL`, `Telecomunicaciones`, y explica brevemente el contenido de cada una.
#    - **Contribución**: Si el proyecto es colaborativo, indica las reglas para contribuir, nombrando prácticas de ramas y pull requests para facilitar futuras colaboraciones.
#
# </div>
#
# **Descripción**
#
# El servicio de telefonía virtual CallMeMaybe está desarrollando una nueva función que brindará a los supervisores y las supervisores información sobre los operadores menos eficaces. Se considera que un operador es ineficaz si tiene una gran cantidad de llamadas entrantes perdidas (internas y externas) y un tiempo de espera prolongado para las llamadas entrantes. Además, si se supone que un operador debe realizar llamadas salientes, un número reducido de ellas también será un signo de ineficacia.
#
# - Lleva a cabo el análisis exploratorio de datos
# - Identificar operadores ineficaces
# - Prueba las hipótesis estadísticas
#
# **Descripción de los datos**
#
# Los datasets contienen información sobre el uso del servicio de telefonía virtual CallMeMaybe. Sus clientes son organizaciones que necesitan distribuir gran cantidad de llamadas entrantes entre varios operadores, o realizar llamadas salientes a través de sus operadores. Los operadores también pueden realizar llamadas internas para comunicarse entre ellos. Estas llamadas se realizan a través de la red de CallMeMaybe.
#
# El dataset comprimido `telecom_dataset_us.csv` contiene las siguientes columnas:
#
# - `user_id`: ID de la cuenta de cliente
# - `date`: fecha en la que se recuperaron las estadísticas
# - `direction`: "dirección" de llamada (`out` para saliente, `in` para entrante)
# - `internal`: si la llamada fue interna (entre los operadores de un cliente o clienta)
# - `operator_id`: identificador del operador
# - `is_missed_call`: si fue una llamada perdida
# - `calls_count`: número de llamadas
# - `call_duration`: duración de la llamada (sin incluir el tiempo de espera)
# - `total_call_duration`: duración de la llamada (incluido el tiempo de espera)
#
#
#
# El conjunto de datos `telecom_clients_us.csv` tiene las siguientes columnas:
#
# - `user_id`: ID de usuario/a
# - `tariff_plan`: tarifa actual de la clientela
# - `date_start`: fecha de registro de la clientela
#
# Haz una lista de 5 a 10 fuentes (documentación, artículos, etc) que usaste mientras trabajabas en el proyecto. Brinda explicaciones breves sobre las preguntas que cada fuente te ayudó a responder. Prepara una presentación con tus conclusiones. Puedes usar cualquier herramienta que quieras para hacer la presentación, pero debes enviarla en PDF. Coloca el enlace en el cuerpo del proyecto principal.

# %% [markdown]
# ## Actividades Propuestas:
#
# 1. **Carga y Exploración de Datos (Python)**
#    - **Descripción**: Esta actividad consiste en cargar ambos datasets (`telecom_dataset_us.csv` y `telecom_clients_us.csv`) usando pandas en Python. Se debe realizar una exploración preliminar de los datos para obtener una comprensión básica de las variables, tipos de datos y presencia de valores faltantes.
#    - **Objetivo**: Conocer la estructura de los datos y realizar una limpieza inicial.
#    - **Herramientas**: Pandas, Matplotlib/Seaborn.
#    - **Pasos**:
#      1. Cargar ambos datasets.
#      2. Mostrar un resumen de las columnas, tipos de datos y verificar valores faltantes.
#      3. Revisar las estadísticas descriptivas básicas (media, mediana, desviación estándar, etc.).
#
# 2. **Análisis Exploratorio de Datos (Python)**
#    - **Descripción**: Se explorarán los datos para descubrir patrones, outliers y distribuciones de variables clave, como la duración de las llamadas, número de llamadas perdidas, y tiempos de espera.
#    - **Objetivo**: Identificar patrones en las llamadas entrantes, salientes, y las internas.
#    - **Herramientas**: Pandas, Matplotlib/Seaborn.
#    - **Pasos**:
#      1. Analizar la distribución de la duración de llamadas (`call_duration` y `total_call_duration`).
#      2. Visualizar la distribución de llamadas internas y externas (gráfico circular).
#      3. Crear un filtro para la dirección de las llamadas (`in` o `out`).
#      4. Graficar un histograma del número de llamadas por día.
#
# 3. **Identificación de Operadores Ineficaces (Python)**
#    - **Descripción**: Se analizarán métricas clave como la proporción de llamadas perdidas, la duración del tiempo de espera, y la baja cantidad de llamadas salientes para identificar operadores ineficaces.
#    - **Objetivo**: Detectar a los operadores que cumplen con las condiciones de ineficacia (llamadas perdidas, largos tiempos de espera, bajo número de llamadas salientes).
#    - **Herramientas**: Pandas, NumPy.
#    - **Pasos**:
#      1. Definir los umbrales para considerar un operador como ineficaz.
#      2. Calcular la proporción de llamadas perdidas por operador.
#      3. Analizar la cantidad de llamadas salientes realizadas por operador.
#      4. Evaluar el tiempo de espera promedio de cada operador.
#
# 4. **Pruebas de Hipótesis Estadísticas (Python)**
#    - **Descripción**: Utilizar métodos estadísticos para comprobar si las diferencias en la cantidad de llamadas perdidas y la duración de espera entre operadores son significativas.
#    - **Objetivo**: Validar si los operadores identificados son significativamente menos eficaces que el resto.
#    - **Herramientas**: SciPy, Statsmodels.
#    - **Pasos**:
#      1. Realizar pruebas t para comparar la media de llamadas perdidas entre operadores ineficaces y eficaces.
#      2. Realizar análisis ANOVA si hay más de dos grupos de operadores a comparar.
#      3. Comparación de Duraciones de Llamadas y Tiempos de Espera
#
# 5. **Segmentación de Operadores por Eficiencia (Python)**
#    Crear una segmentación de los operadores en grupos según su nivel de eficacia (eficaz, ineficaz moderado, muy ineficaz) usando clustering (K-means) para facilitar la visualización en Tableau.
#    - **Objetivo**: Clasificar automáticamente a los operadores según múltiples criterios.
#    - **Herramientas**: Scikit-learn para clustering, Tableau para visualización.
#    - **Pasos**:
#      1. Aplicar clustering en Python basado en las métricas clave.
#      2. Visualizar los resultados de los clústeres en Tableau.
#
# 6. **Visualización de Resultados en Tableau Public**
#    - **Descripción**: Importar los datos preprocesados desde Python a Tableau para crear las visualizaciones que ayuden a analizar los operadores ineficaces y la distribución de llamadas.
#    - **Objetivo**: Visualizar claramente los operadores ineficaces y otros insights del dataset.
#    - **Herramientas**: Tableau Public.
#    - **Pasos**:
#      1. Crear histogramas para la duración de llamadas y número de llamadas por día.
#      2. Crear gráficos circulares que muestren la participación de llamadas internas y externas.
#      3. Agregar filtros por tipo de llamada (dirección y llamadas internas/externas).
#      4. Crear gráficos que muestren los operadores ineficaces identificados.

# %% [markdown]
# ## 1. Carga y Exploración de Datos (Python)

# %%
# Cargar todas las librerías
from scipy import stats as st
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np
import pandas as pd
import math as mt
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import re
import os
from plotly import graph_objects as go
from scipy.stats import shapiro, kstest
#
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
# La función data_load() carga un archivo CSV desde una carpeta llamada 'datasets' y devuelve un DataFrame con los datos.

def data_load(file = 'telecom_dataset_us.csv'):	
    ruta_archivo = os.path.join('datasets', file)
    data = pd.read_csv(
	    ruta_archivo
	)
    return data

# %%
# Se llama a la función data_loas() y se guarda el datarame resultante en 'clients'
clients = data_load('telecom_clients_us.csv')
# clients.columns = dataset.columns.str.lower()
clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      732 non-null    int64
#  1   tariff_plan  732 non-null    object
#  2   date_start   732 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 17.3+ KB

# %%
# Se llama a la función data_load() y se guarda el datarame resultante en 'dataset'
dataset = data_load('telecom_dataset_us.csv')
# dataset.columns = dataset.columns.str.lower()
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53902 entries, 0 to 53901
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              53902 non-null  int64
#  1   date                 53902 non-null  object
#  2   direction            53902 non-null  object
#  3   internal             53785 non-null  object
#  4   operator_id          45730 non-null  float64
#  5   is_missed_call       53902 non-null  bool
#  6   calls_count          53902 non-null  int64
#  7   call_duration        53902 non-null  int64
#  8   total_call_duration  53902 non-null  int64
# dtypes: bool(1), float64(1), int64(4), object(3)
# memory usage: 3.3+ MB

# %%
# Se convierte la columna 'date' a 'datetime'
# Se agrega la columna 'period' con solo los periodes de tiempo de Año - Mes de los datos

dataset['date'] = pd.to_datetime(dataset['date'])
dataset['date'] = dataset['date'].dt.strftime('%Y-%m-%d')
dataset['date'] = pd.to_datetime(dataset['date'])
dataset['period'] = dataset['date'].dt.strftime('%Y-%m')
dataset['period'] = pd.to_datetime(dataset['period'])

# %%
# Se muestran las primeas 5 columnas del dataframe

dataset.head()
# Out:
#    user_id       date direction internal  operator_id  is_missed_call  \
# 0   166377 2019-08-04        in    False          NaN            True
# 1   166377 2019-08-05       out     True     880022.0            True
# 2   166377 2019-08-05       out     True     880020.0            True
# 3   166377 2019-08-05       out     True     880020.0           False
# 4   166377 2019-08-05       out    False     880022.0            True
#
#    calls_count  call_duration  total_call_duration     period
# 0            2              0                    4 2019-08-01
# 1            3              0                    5 2019-08-01
# 2            1              0                    1 2019-08-01
# 3            1             10                   18 2019-08-01
# 4            3              0                   25 2019-08-01

# %%
# Se eliminan las filas con valores vacíos, dado que no es posible identificar el operados o el tipo de llamada.

data = dataset.dropna(subset=['operator_id'])
data = data.dropna(subset=['internal'])

# Se convierte el tipo de la columna 'operator_id' a entero

data['operator_id'] = data['operator_id'].astype(int)

# %%
#Se calcula la proporcion de datos restantes en porcentaje

print((len(data)/len(dataset))*100, ' %')
# Out:
# 84.7278394122667  %

# %%
# Se calcula el tiempo de espera y se guarda en una nueva columna llamada 'wait time'

data['wait_time'] = data['total_call_duration'] - data['call_duration']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45670 entries, 1 to 53900
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              45670 non-null  int64
#  1   date                 45670 non-null  datetime64[ns]
#  2   direction            45670 non-null  object
#  3   internal             45670 non-null  object
#  4   operator_id          45670 non-null  int32
#  5   is_missed_call       45670 non-null  bool
#  6   calls_count          45670 non-null  int64
#  7   call_duration        45670 non-null  int64
#  8   total_call_duration  45670 non-null  int64
#  9   period               45670 non-null  datetime64[ns]
#  10  wait_time            45670 non-null  int64
# dtypes: bool(1), datetime64[ns](2), int32(1), int64(5), object(2)
# memory usage: 3.7+ MB

# %%
data.head()
# Out:
#    user_id       date direction internal  operator_id  is_missed_call  \
# 1   166377 2019-08-05       out     True       880022            True
# 2   166377 2019-08-05       out     True       880020            True
# 3   166377 2019-08-05       out     True       880020           False
# 4   166377 2019-08-05       out    False       880022            True
# 5   166377 2019-08-05       out    False       880020           False
#
#    calls_count  call_duration  total_call_duration     period  wait_time
# 1            3              0                    5 2019-08-01          5
# 2            1              0                    1 2019-08-01          1
# 3            1             10                   18 2019-08-01          8
# 4            3              0                   25 2019-08-01         25
# 5            2              3                   29 2019-08-01         26

# %%
# Se describen los dato del dataframe resultante

data[['date','calls_count', 'call_duration', 'total_call_duration','period', 'wait_time']].describe()
# Out:
#                                 date   calls_count  call_duration  \
# count                          45670  45670.000000   45670.000000
# mean   2019-10-23 16:08:16.290781696     16.925203    1010.934399
# min              2019-08-02 00:00:00      1.000000       0.000000
# 25%              2019-10-06 00:00:00      1.000000       0.000000
# 50%              2019-10-28 00:00:00      4.000000     107.000000
# 75%              2019-11-14 00:00:00     14.000000     774.000000
# max              2019-11-28 00:00:00   4817.000000  144395.000000
# std                              NaN     59.081220    4017.101865
#
#        total_call_duration                         period     wait_time
# count         45670.000000                          45670  45670.000000
# mean           1323.697000  2019-10-07 17:48:37.994307072    312.762601
# min               0.000000            2019-08-01 00:00:00      0.000000
# 25%              68.000000            2019-10-01 00:00:00     19.000000
# ...

# %%
# Se usa un for para validar que no existan valores nulos en las columnas

for col in data.columns:
    print(data[col].unique())
# Out:
# [166377 166391 166392 166399 166405 166406 166407 166428 166481 166482
#  166485 166487 166495 166503 166507 166511 166520 166533 166536 166541
#  166548 166582 166585 166604 166609 166619 166636 166649 166658 166660
#  166666 166669 166671 166677 166678 166680 166688 166691 166692 166697
#  166708 166711 166713 166717 166725 166726 166727 166732 166774 166782
#  166800 166803 166812 166813 166833 166836 166837 166839 166843 166874
#  166879 166884 166896 166899 166901 166908 166916 166936 166939 166940
#  166941 166946 166955 166958 166971 166973 166974 166975 166983 166985
#  166993 166997 167002 167003 167004 167009 167011 167012 167016 167031
#  167035 167052 167053 167059 167060 167061 167071 167078 167079 167082
#  167102 167109 167110 167112 167113 167122 167124 167125 167130 167139
#  167141 167144 167150 167158 167162 167172 167175 167176 167180 167183
#  167185 167188 167189 167199 167200 167235 167238 167242 167244 167246
# ...

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - ¡Excelente trabajo! Has cargado y explorado los datos con éxito. La verificación de columnas, tipos de datos y valores faltantes brinda una base sólida para las siguientes etapas. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>

# %% [markdown]
# ## 2. Análisis Exploratorio de Datos (Python)
#
# 1. Analizar la distribución de la duración de llamadas (`call_duration` y `total_call_duration`).

# %%
#Se imprimen histogramas de las métricas de interés

for col in ['call_duration', 'total_call_duration', 'wait_time']:
  sns.histplot(data[col], bins = 20)
  plt.show()

# %%
for col in ['call_duration', 'total_call_duration', 'wait_time']:
    percentiles = np.percentile(data[col], [90, 95, 99])
    print(f'Percentiles de', col, ':\n', '[90      95      99] % \n', percentiles)
# Out:
# Percentiles de call_duration :
#  [90      95      99] %
#  [ 2425.    4173.1  11162.79]
# Percentiles de total_call_duration :
#  [90      95      99] %
#  [ 2966.    5036.   13579.04]
# Percentiles de wait_time :
#  [90      95      99] %
#  [ 660.   1234.   3530.24]

# %% [markdown]
# 2. Visualizar la distribución de llamadas internas y externas (gráfico circular).

# %%
name_rest = data['internal'].unique()
values = []

values.append(data.groupby('internal')['internal'].count().iloc[0])
values.append(data.groupby('internal')['internal'].count().iloc[1])

fig = go.Figure(data=[go.Pie(labels=name_rest, values=values)])
fig.show()

# %%
name_rest = data['direction'].unique()
values = []

values.append(data.groupby('direction')['direction'].count().iloc[0])
values.append(data.groupby('direction')['direction'].count().iloc[1])

fig = go.Figure(data=[go.Pie(labels=name_rest, values=values)])
fig.show()

# %% [markdown]
# 3. Crear un filtro para la dirección de las llamadas (`in` o `out`).

# %%
call_in = data[data['direction'] == 'in']
call_out = data[data['direction'] == 'out']

# %%
calls_per_day = data.groupby('date', as_index= False)['calls_count'].sum()
calls_per_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         118 non-null    datetime64[ns]
#  1   calls_count  118 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.0 KB

# %% [markdown]
# 4. Graficar un histograma del número de llamadas por día.

# %%
fig = px.bar(calls_per_day, x='date', y='calls_count', title='Cantidad de llamadas por día')
fig.update_xaxes(tickangle=45)
fig.show()

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - ¡Excelente trabajo en el análisis exploratorio de datos! Los histogramas para la duración y el tiempo de espera permiten visualizar las distribuciones y centrar la atención en los percentiles clave. La gráfica circular y el filtro por dirección ayudan a analizar eficazmente la proporción de llamadas internas, externas, y la distribución de llamadas entrantes y salientes.
#
# </div> <div class="alert alert-block alert-warning"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Atención</b> ⚠️ - Observa que la función distplot está en desuso y será eliminada en versiones futuras de Seaborn. Para mayor compatibilidad, considera actualizar tu código utilizando displot o histplot, que ofrecen funcionalidades similares y optimizadas. Esto fortalecerá la durabilidad y legibilidad del código a largo plazo.
#
# </div>

# %% [markdown]
# ## 3. Identificación de Operadores Ineficaces (Python)

# %% [markdown]
# 1. Definir los umbrales para considerar un operador como ineficaz.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45670 entries, 1 to 53900
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              45670 non-null  int64
#  1   date                 45670 non-null  datetime64[ns]
#  2   direction            45670 non-null  object
#  3   internal             45670 non-null  object
#  4   operator_id          45670 non-null  int32
#  5   is_missed_call       45670 non-null  bool
#  6   calls_count          45670 non-null  int64
#  7   call_duration        45670 non-null  int64
#  8   total_call_duration  45670 non-null  int64
#  9   period               45670 non-null  datetime64[ns]
#  10  wait_time            45670 non-null  int64
# dtypes: bool(1), datetime64[ns](2), int32(1), int64(5), object(2)
# memory usage: 3.7+ MB

# %%
for col in ['call_duration', 'total_call_duration', 'wait_time']:
    percentiles = np.percentile(data[col], [90, 95, 99])
    print(f'Percentiles de', col, ':\n', '[90      95      99] % \n', percentiles)
# Out:
# Percentiles de call_duration :
#  [90      95      99] %
#  [ 2425.    4173.1  11162.79]
# Percentiles de total_call_duration :
#  [90      95      99] %
#  [ 2966.    5036.   13579.04]
# Percentiles de wait_time :
#  [90      95      99] %
#  [ 660.   1234.   3530.24]

# %%
missed_calls = data.groupby('operator_id', as_index= False)['is_missed_call'].count().sort_values('is_missed_call', ascending= False)
print(missed_calls)
# Out:
#       operator_id  is_missed_call
# 204        901884             348
# 203        901880             335
# 108        893804             325
# 28         885876             319
# 78         891410             290
# ...           ...             ...
# 988        955436               1
# 331        909894               1
# 984        955086               1
# 326        909452               1
# 1091       973286               1
#
# [1092 rows x 2 columns]

# %%
percentiles = np.percentile(missed_calls['is_missed_call'], [75, 90, 95, 99])
print(f'Percentiles de is_missed_call', ':\n', '[75      90      95      99] % \n', percentiles)
# Out:
# Percentiles de is_missed_call :
#  [75      90      95      99] %
#  [ 54.   108.9  154.45 254.63]

# %%
missed_calls_filtered = missed_calls[missed_calls['is_missed_call'] < 154.45]

# %%
missed_calls_filtered['is_missed_call'].describe()
# Out:
# count    1037.000000
# mean       32.622951
# std        35.446621
# min         1.000000
# 25%         5.000000
# 50%        18.000000
# 75%        48.000000
# max       154.000000
# Name: is_missed_call, dtype: float64

# %%
print(missed_calls[missed_calls['is_missed_call'] <= 20])
# Out:
#       operator_id  is_missed_call
# 664        935958              20
# 614        931914              20
# 1047       964716              20
# 654        935216              20
# 557        926872              20
# ...           ...             ...
# 988        955436               1
# 331        909894               1
# 984        955086               1
# 326        909452               1
# 1091       973286               1
#
# [545 rows x 2 columns]

# %%
out_calls = data[data['direction'] == 'out']
out_calls = out_calls.groupby('operator_id', as_index= False)['direction'].count().sort_values('direction')
print(out_calls)
# Out:
#      operator_id  direction
# 791       955068          1
# 250       907998          1
# 486       930816          1
# 814       958458          1
# 495       932246          1
# ..           ...        ...
# 68        891414        212
# 27        887276        215
# 24        885876        216
# 163       901880        216
# 164       901884        246
#
# [882 rows x 2 columns]

# %%
percentiles = np.percentile(out_calls['direction'], [75, 90, 95, 99])
print(f'Percentiles de is_missed_call', ':\n', '[75      90      95      99] % \n', percentiles)
# Out:
# Percentiles de is_missed_call :
#  [75      90      95      99] %
#  [ 49.75  92.   124.8  186.19]

# %%
data = data[data['wait_time'] <= 1234]
data.head()
# Out:
#    user_id       date direction internal  operator_id  is_missed_call  \
# 1   166377 2019-08-05       out     True       880022            True
# 2   166377 2019-08-05       out     True       880020            True
# 3   166377 2019-08-05       out     True       880020           False
# 4   166377 2019-08-05       out    False       880022            True
# 5   166377 2019-08-05       out    False       880020           False
#
#    calls_count  call_duration  total_call_duration     period  wait_time
# 1            3              0                    5 2019-08-01          5
# 2            1              0                    1 2019-08-01          1
# 3            1             10                   18 2019-08-01          8
# 4            3              0                   25 2019-08-01         25
# 5            2              3                   29 2019-08-01         26

# %%
data_cln = data[data['wait_time'] <= 3530.24]

# %%
data_cln.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43387 entries, 1 to 53900
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              43387 non-null  int64
#  1   date                 43387 non-null  datetime64[ns]
#  2   direction            43387 non-null  object
#  3   internal             43387 non-null  object
#  4   operator_id          43387 non-null  int32
#  5   is_missed_call       43387 non-null  bool
#  6   calls_count          43387 non-null  int64
#  7   call_duration        43387 non-null  int64
#  8   total_call_duration  43387 non-null  int64
#  9   period               43387 non-null  datetime64[ns]
#  10  wait_time            43387 non-null  int64
# dtypes: bool(1), datetime64[ns](2), int32(1), int64(5), object(2)
# memory usage: 3.5+ MB

# %%
data_cln.describe()
# Out:
#              user_id                           date    operator_id  \
# count   43387.000000                          43387   43387.000000
# mean   167284.855740  2019-10-23 22:07:13.291078144  916149.406274
# min    166377.000000            2019-08-02 00:00:00  879896.000000
# 25%    166782.000000            2019-10-07 00:00:00  900594.000000
# 50%    167150.000000            2019-10-29 00:00:00  912296.000000
# 75%    167799.000000            2019-11-15 00:00:00  937362.000000
# max    168606.000000            2019-11-28 00:00:00  973286.000000
# std       594.172074                            NaN   21153.983606
#
#         calls_count  call_duration  total_call_duration  \
# count  43387.000000   43387.000000         43387.000000
# mean       9.514394     682.871206           834.353816
# min        1.000000       0.000000             0.000000
# 25%        1.000000       0.000000            62.000000
# 50%        4.000000     108.000000           255.000000
# ...

# %%
for col in ['call_duration', 'total_call_duration', 'wait_time']:
  sns.histplot(data_cln[col], bins = 20)
  plt.show()

# %%
wait_time = data.groupby('operator_id', as_index= False)['wait_time'].sum().sort_values('wait_time', ascending= False)
print(wait_time)
# Out:
#       operator_id  wait_time
# 1          879898      94114
# 108        893804      84701
# 497        921318      68422
# 254        905538      60412
# 613        931458      59844
# ...           ...        ...
# 874        946454          0
# 982        955068          0
# 386        914626          0
# 448        919364          0
# 1011       958458          0
#
# [1092 rows x 2 columns]

# %%
fig = px.histogram(data_cln, x='wait_time', nbins=25)
fig.update_xaxes(tickangle=45)
fig.show()

# %%
fig = px.histogram(missed_calls, x='is_missed_call', nbins=50)
fig.update_xaxes(tickangle=45)
fig.show()

# %%
missed_calls_filtered.describe()
# Out:
#          operator_id  is_missed_call
# count    1037.000000     1037.000000
# mean   926880.138862       32.622951
# std     22493.530020       35.446621
# min    879896.000000        1.000000
# 25%    907982.000000        5.000000
# 50%    928404.000000       18.000000
# 75%    944646.000000       48.000000
# max    973286.000000      154.000000

# %%
fig = px.histogram(out_calls, x='direction', nbins=50)
fig.update_xaxes(tickangle=45)
fig.show()

# %%
out_calls.describe()
# Out:
#          operator_id   direction
# count     882.000000  882.000000
# mean   925658.340136   35.960317
# std     22862.558731   41.965280
# min    879896.000000    1.000000
# 25%    906394.500000    5.000000
# 50%    924959.000000   21.000000
# 75%    943630.000000   49.750000
# max    973120.000000  246.000000

# %% [markdown]
# Se tomaron los siguientes umbrales para considerar como ineficaces a los operadores:
#
# -   Llamadas salientes menores a: `50`
# -   Llamadas perdidas mayores a: `50`
# -   Tiempo de espera mayor a: `175`

# %%
bad_op_wait_time = wait_time[wait_time['wait_time'] > 175]['operator_id']
bad_op_wait_time = bad_op_wait_time.reset_index(drop= True)
bad_op_missed_calls = missed_calls[missed_calls['is_missed_call'] > 50]['operator_id']
bad_op_missed_calls = bad_op_missed_calls.reset_index(drop= True)
bad_op_out_calls = out_calls[out_calls['direction'] < 50]['operator_id']
bad_op_out_calls = bad_op_out_calls.reset_index(drop= True)

# %% [markdown]
# 2. Calcular la proporción de llamadas perdidas por operador.
# 3. Analizar la cantidad de llamadas salientes realizadas por operador.
# 4. Evaluar el tiempo de espera promedio de cada operador.

# %%
bad_operators = pd.concat([bad_op_wait_time, bad_op_missed_calls, bad_op_out_calls], ignore_index= True)
bad_operators = bad_operators.drop_duplicates()
bad_operators.reset_index(drop=True, inplace=True)
print(bad_operators)
# Out:
# 0      879898
# 1      893804
# 2      921318
# 3      905538
# 4      931458
#         ...
# 971    955090
# 972    924370
# 973    937422
# 974    905934
# 975    919364
# Name: operator_id, Length: 976, dtype: int32

# %%
bad_op_data = data[data['operator_id'].isin(bad_operators)]
good_op_data = data[~ data['operator_id'].isin(bad_operators)]

bad_op_data.info()
good_op_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43025 entries, 1 to 53900
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              43025 non-null  int64
#  1   date                 43025 non-null  datetime64[ns]
#  2   direction            43025 non-null  object
#  3   internal             43025 non-null  object
#  4   operator_id          43025 non-null  int32
#  5   is_missed_call       43025 non-null  bool
#  6   calls_count          43025 non-null  int64
#  7   call_duration        43025 non-null  int64
#  8   total_call_duration  43025 non-null  int64
#  9   period               43025 non-null  datetime64[ns]
#  10  wait_time            43025 non-null  int64
#  11  missed_call_rate     43025 non-null  float64
# dtypes: bool(1), datetime64[ns](2), float64(1), int32(1), int64(5), object(2)
# memory usage: 3.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
bad_op_wait_time = wait_time[wait_time['operator_id'].isin(bad_operators)]
bad_op_wait_time = bad_op_wait_time.reset_index(drop= True)
bad_op_missed_calls = missed_calls[missed_calls['operator_id'].isin(bad_operators)]
bad_op_missed_calls = bad_op_missed_calls.reset_index(drop= True)
bad_op_out_calls = out_calls[out_calls['operator_id'].isin(bad_operators)]
bad_op_out_calls = bad_op_out_calls.reset_index(drop= True)

# %%
bad_op_metrics = bad_op_wait_time.merge(bad_op_missed_calls, on='operator_id', how='outer').merge(bad_op_out_calls, on='operator_id', how='outer')
bad_op_metrics.columns = ['operator_id', 'wait_time', 'missed_calls', 'out_calls']
bad_op_metrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 976 entries, 0 to 975
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   operator_id   976 non-null    int32
#  1   wait_time     976 non-null    int64
#  2   missed_calls  976 non-null    int64
#  3   out_calls     882 non-null    float64
# dtypes: float64(1), int32(1), int64(2)
# memory usage: 26.8 KB

# %%
bad_op_metrics.head()
# Out:
#    operator_id  wait_time  missed_calls  out_calls
# 0       879896      14166           128      105.0
# 1       879898      94114           250      187.0
# 2       880020        334            22       14.0
# 3       880022       4375            76       68.0
# 4       880026      23992           198      179.0

# %%
# Corrección: guardando el archivo en formato pickle
data.to_pickle('dataset.pkl')
bad_op_metrics.to_pickle('bad_op_metrics.pkl')
# bad_op_metrics.to_csv('bad_op_metrics.csv', index=False)
# data.to_csv('dataset.csv', index=False)

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - ¡Excelente trabajo en la identificación de operadores ineficaces! Los umbrales definidos para el tiempo de espera, las llamadas perdidas y las llamadas salientes ayudan a identificar correctamente a los operadores menos eficaces. Los resultados filtrados y las agrupaciones por operador proporcionan información útil para el análisis posterior.
#
# </div> <div class="alert alert-block alert-warning"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Atención</b> ⚠️ - Observé comentarios de código sin utilizar en esta sección. Es importante eliminarlos, ya que el código no usado puede confundir al lector y afecta la claridad general del proyecto. Además, considera la opción de guardar los datos en formato pickle en lugar de csv si el proyecto implica leer y escribir grandes volúmenes de datos varias veces. pickle es más rápido y preserva los tipos de datos originales, mejorando el rendimiento y optimización.
#
# </div>

# %% [markdown]
# ## 4. Pruebas de Hipótesis Estadísticas

# %%
data['missed_call_rate'] = data['is_missed_call'] / data['calls_count']

# Segmentar operadores en eficaces e ineficaces (esto dependerá de tus umbrales)
# Ejemplo: si más del 30% de las llamadas fueron perdidas, clasificamos como ineficaz
threshold_missed_calls = 0.30
ineficaces = data[data['missed_call_rate'] > threshold_missed_calls]
eficaces = data[data['missed_call_rate'] <= threshold_missed_calls]

# %%
print('Tamaño de los grupos:')
print('Operadores ineficaces: ', len(ineficaces))
print('Operadores eficaces: ', len(eficaces))
# Out:
# Tamaño de los grupos:
# Operadores ineficaces:  7313
# Operadores eficaces:  36074

# %% [markdown]
# **Supuesto de Normalidad**
# Podemos verificar si los datos de las dos muestras (eficaces e ineficaces) siguen una distribución normal, alusar la prueba de Shapiro-Wilk en una muestra grande (más de 5,000 datos), el valor p calculado puede no ser preciso. Para grandes muestras, existen alternativas que funcionan mejor en la verificación de normalidad:
#
# Como alternativa para pruebas de normalidad en muestras grandes, se usó la prueba de Anderson-Darling:
#
# Es adecuada para muestras grandes y proporciona una estadística de bondad de ajuste con varios niveles de significancia.
# No entrega un valor p, sino que compara el estadístico con valores críticos para determinar si se cumple la normalidad.

# %%
from scipy.stats import anderson

# Anderson-Darling Test para eficaces
result_eficaz = anderson(eficaces['missed_call_rate'], dist='norm')
print("Anderson-Darling Test para eficaces - Estadístico:", result_eficaz.statistic)
print("Valores críticos:", result_eficaz.critical_values)
print("Niveles de significancia:", result_eficaz.significance_level)

# Anderson-Darling Test para ineficaces
result_ineficaz = anderson(ineficaces['missed_call_rate'], dist='norm')
print("Anderson-Darling Test para ineficaces - Estadístico:", result_ineficaz.statistic)
print("Valores críticos:", result_ineficaz.critical_values)
print("Niveles de significancia:", result_ineficaz.significance_level)
# Out:
# Anderson-Darling Test para eficaces - Estadístico: 8762.903093656721
# Valores críticos: [0.576 0.656 0.787 0.918 1.092]
# Niveles de significancia: [15.  10.   5.   2.5  1. ]
# Anderson-Darling Test para ineficaces - Estadístico: 1093.3714850176639
# Valores críticos: [0.576 0.656 0.787 0.917 1.091]
# Niveles de significancia: [15.  10.   5.   2.5  1. ]

# %% [markdown]
# **Supuesto de Homogeneidad de Varianzas**
#
# Para verificar la homogeneidad de varianzas entre los grupos, puedes utilizar:
#
# Prueba de Levene: Esta prueba evalúa si dos o más grupos tienen varianzas iguales. Un valor p menor que 0.05 indica que las varianzas no son homogéneas.
# Prueba de Bartlett: Otra prueba común, aunque es más sensible a desviaciones de la normalidad.

# %%
from scipy.stats import levene, bartlett

# Prueba de Levene para la homogeneidad de varianzas
stat_levene, p_levene = levene(eficaces['missed_call_rate'], ineficaces['missed_call_rate'])
print("Prueba de Levene - Estadístico:", stat_levene, ", p-valor:", p_levene)

# Prueba de Bartlett (si los datos son normales)
stat_bartlett, p_bartlett = bartlett(eficaces['missed_call_rate'], ineficaces['missed_call_rate'])
print("Prueba de Bartlett - Estadístico:", stat_bartlett, ", p-valor:", p_bartlett)
# Out:
# Prueba de Levene - Estadístico: 16935.13950223183 , p-valor: 0.0
# Prueba de Bartlett - Estadístico: 47808.33743409289 , p-valor: 0.0

# %% [markdown]
# Los resultados de las pruebas indican que:
#
# ### 1. **Prueba de Anderson-Darling para Normalidad**
#    - Ambos grupos (eficaces e ineficaces) tienen un estadístico Anderson-Darling mucho mayor que los valores críticos en todos los niveles de significancia (0.576 a 1.092). Esto significa que los datos de ambos grupos **no siguen una distribución normal**, dado que los valores exceden ampliamente los umbrales.
#
# ### 2. **Pruebas de Homogeneidad de Varianzas (Levene y Bartlett)**
#    - Los valores p de ambas pruebas (Levene y Bartlett) son 0.0, lo cual es menor que 0.05. Esto indica que **no se cumple el supuesto de homogeneidad de varianzas** entre los dos grupos, lo que significa que las varianzas son significativamente diferentes.
#
# ### **Conclusión y Sugerencias**
#
# Debido a que los datos no cumplen con la normalidad ni con la homogeneidad de varianzas, las pruebas paramétricas (como la prueba t y ANOVA) no son apropiadas. Las opciones recomendadas son:
#
# 1. **Prueba de Mann-Whitney U** (para dos muestras no normales y con varianzas desiguales): Es una prueba no paramétrica que evalúa si hay diferencias significativas entre dos muestras independientes.

# %%
from scipy.stats import mannwhitneyu

# Prueba de Mann-Whitney U
stat_mw, p_mw = mannwhitneyu(eficaces['missed_call_rate'], ineficaces['missed_call_rate'], alternative='two-sided')
print("Prueba de Mann-Whitney U - Estadístico:", stat_mw, ", p-valor:", p_mw)
# Out:
# Prueba de Mann-Whitney U - Estadístico: 0.0 , p-valor: 0.0

# %% [markdown]
# Un resultado con un **estadístico de Mann-Whitney U de 0** y un **valor p de 0.0** indica una diferencia altamente significativa entre los dos grupos que comparaste (eficaces e ineficaces) en cuanto a la tasa de llamadas perdidas. En este caso:
#
# - **Estadístico U = 0** significa que no hay solapamiento en las distribuciones de los dos grupos. Esto sugiere que, según la métrica de tasa de llamadas perdidas, los grupos de eficaces e ineficaces son completamente distintos.
# - **Valor p = 0.0** (menor a 0.05) indica que la diferencia entre los grupos es estadísticamente significativa, por lo que rechazas la hipótesis nula de que ambos grupos tienen la misma distribución en la tasa de llamadas perdidas.
#
# ### Interpretación
# Esto confirma que los operadores clasificados como "ineficaces" tienen una tasa de llamadas perdidas significativamente distinta (más alta) en comparación con los operadores "eficaces." Esto respalda la segmentación que hiciste para identificar a los operadores menos eficaces y podría ser una base sólida para generar alertas o acciones de mejora dirigidas a estos operadores en el sistema CallMeMaybe.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Es importante realizar la validación de los supuestos para las pruebas t y ANOVA, como la normalidad y homogeneidad de varianzas, antes de aplicar estos métodos. Esto garantiza la precisión de los resultados estadísticos y la confiabilidad en las conclusiones derivadas. Sin estas validaciones, los resultados pueden no ser completamente precisos y afectar la validez del análisis.
#
# </div>

# %% [markdown]
# 3. Comparación de Duraciones de Llamadas y Tiempos de Espera

# %%
# Realizar la prueba de Mann-Whitney U en la duración de llamadas
stat_duration, p_duration = mannwhitneyu(eficaces['call_duration'], ineficaces['call_duration'], alternative='two-sided')
print("Prueba de Mann-Whitney U para duración de llamadas - Estadístico:", stat_duration, ", p-valor:", p_duration)
# Out:
# Prueba de Mann-Whitney U para duración de llamadas - Estadístico: 236062364.0 , p-valor: 0.0

# %% [markdown]
# Los resultados obtenidos de la **prueba de Mann-Whitney U** para la duración de las llamadas son significativos:
#
# - **Estadístico U = 236062364.0**: Este valor indica la posición de las distribuciones de duración de llamadas entre los operadores eficaces e ineficaces. Un valor alto en este caso sugiere que hay una diferencia considerable en la duración de las llamadas entre los dos grupos.
#
# - **Valor p = 0.0**: Este valor es mucho menor que 0.05, lo que indica que hay una diferencia estadísticamente significativa en la duración de las llamadas entre los operadores eficaces e ineficaces. Esto significa que puedes rechazar la hipótesis nula de que ambos grupos tienen la misma distribución en cuanto a la duración de las llamadas.
#
# ### Interpretación
# Este resultado sugiere que la duración promedio de las llamadas para los operadores clasificados como **ineficaces** es significativamente diferente (posiblemente más corta o más larga, dependiendo de la naturaleza de tus datos) en comparación con los operadores **eficaces**. Esto puede ofrecer una pista adicional sobre las razones de ineficacia, como el tiempo que pasan en las llamadas o el manejo de las mismas.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - Excelente uso de pruebas de hipótesis para comparar las proporciones de llamadas perdidas y la duración de llamadas entre operadores eficaces e ineficaces. Los resultados y las interpretaciones están claramente presentados y ayudan a visualizar las diferencias significativas entre los grupos.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - En el análisis ANOVA, asegúrate de verificar que las medias sean comparables y que se realice un análisis post hoc si el número de grupos es superior a dos. Esto proporcionará una visión más detallada de las diferencias específicas entre los grupos de eficacia y permitirá interpretar mejor los resultados significativos obtenidos.
#
# </div>

# %% [markdown]
# ## 5. Segmentación de Operadores por Eficiencia:
# 1. Preparar los Datos para Clustering

# %%
# Agrupar por operador y calcular métricas clave
df_operator_metrics = data.groupby('operator_id').agg({
    'is_missed_call': 'sum',  # Total de llamadas perdidas
    'calls_count': 'sum',  # Total de llamadas
    'call_duration': 'mean',  # Duración promedio de llamadas
    'total_call_duration': 'mean'  # Duración total de llamadas (incluyendo espera)
}).reset_index()

# Calcular proporción de llamadas perdidas y tiempo de espera promedio
df_operator_metrics['missed_call_rate'] = df_operator_metrics['is_missed_call'] / df_operator_metrics['calls_count']
df_operator_metrics['waiting_time'] = df_operator_metrics['total_call_duration'] - df_operator_metrics['call_duration']

# Seleccionar las métricas relevantes para clustering
X = df_operator_metrics[['missed_call_rate', 'call_duration', 'waiting_time']]

# %% [markdown]
# 2. Escalamiento de los Datos

# %%
# Escalar los datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# 3. Se define el número de clústeres, probar varios valores de k usando el método del codo (elbow method) para encontrar un número adecuado de clústeres.
# Aplicar K-means para Clustering

# %%
# Método del codo para encontrar el número óptimo de clústeres
inertia = []
k_range = range(1, 11)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

# Graficar el método del codo
plt.plot(k_range, inertia, marker='o')
plt.xlabel('Número de Clústeres (k)')
plt.ylabel('Inercia')
plt.title('Método del Codo')
plt.show()

# %%
linked = linkage(X_scaled, method = 'ward')

plt.figure(figsize=(15, 10))  
dendrogram(linked, orientation='top')
plt.title('Agrupación jerárquica')
plt.show()

# %% [markdown]
# Dado los resultados del método del codo y de la agrupación jerárquica se decidieron usar 6 clusters.

# %% [markdown]
# <div class="alert alert-block alert-warning"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Atención</b> ⚠️ - El uso del método del codo está correctamente implementado, pero considera probar otros métodos, como el coeficiente de silueta, para confirmar que el número de clústeres es óptimo. Esto puede brindar una visión más robusta del número de segmentos y mejorar la calidad del agrupamiento.
#
# </div>

# %% [markdown]
# 4. Aplicar K-means para Clustering (Python)

# %%
# Aplicar K-means con el número óptimo de clústeres
kmeans = KMeans(n_clusters=6, random_state=42)
df_operator_metrics['cluster'] = kmeans.fit_predict(X_scaled)

# Ver el número de operadores en cada clúster
df_operator_metrics['cluster'].value_counts()
# Out:
# cluster
# 5    525
# 0    246
# 2    170
# 1     71
# 3     57
# 4     23
# Name: count, dtype: int64

# %% [markdown]
# 5. Interpretar y Renombrar los Grupos de Eficiencia

# %%
# Calcular las métricas promedio de cada grupo
df_operator_metrics.groupby('cluster').agg({
    'missed_call_rate': 'mean',
    'call_duration': 'mean',
    'waiting_time': 'mean'
})

# Asignar nombres a los clústeres
df_operator_metrics['efficiency_label'] = df_operator_metrics['cluster'].map({
    0: 'Eficaz', 
    1: 'Moderadamente Eficaz', 
    2: 'Promedio',
    3: 'Moderadamente Ineficaz',
    4: 'Ineficaz',
    5: 'Altamente Ineficaz'
})

# %% [markdown]
# ## 6. Visualización de Resultados en Tableau Public
#      1. Crear histogramas para la duración de llamadas y número de llamadas por día.
#      2. Crear gráficos circulares que muestren la participación de llamadas internas y externas.
#      3. Agregar filtros por tipo de llamada (dirección y llamadas internas/externas).
#      4. Crear gráficos que muestren los operadores ineficaces identificados.

# %%
# Guardar el archivo CSV para Tableau
df_operator_metrics.to_csv('operator_efficiency_clusters.csv', index=False)
df_operator_metrics.to_pickle('operator_efficiency_clusters.pkl')

# %% [markdown]
# **Segmentación de operadores por eficiencia**
#
# Se categorizaron a los operadores en seis grupos de eficiencia:
# -   Eficaz
# -   Moderadamente Eficaz
# -   Promedio
# -   Moderadamente Ineficaz
# -   Ineficaz
# -   Altamente Ineficaz
#
#
# <img src="Clusters_calls.png" alt="Texto alternativo" width="600" height="560">
#
# **Métricas importantes por grupo**
#
# Los operadores más eficaces tienen altos tiempos de llamada, poco tiempo de espera y pocas llamadas perdidas.
#
# <img src="Clusters_metricas.png" alt="Texto alternativo" width="1000" height="480">

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Excelente trabajo al preparar los datos para el clustering y realizar el cálculo de las métricas clave por operador. La segmentación de operadores por sus tasas de llamadas perdidas y tiempos de espera contribuye al análisis de manera clara y efectiva, proporcionando una visión detallada de su desempeño.
#
# </div> <div class="alert alert-block alert-warning"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Atención</b> ⚠️ - Recuerda revisar los resultados de clustering en función del contexto del negocio para asegurarte de que los nombres asignados a cada clúster reflejan con precisión el rendimiento de cada grupo de operadores. Esto fortalecerá la interpretación de los clústeres y su aplicación práctica.
#
# </div>

# %% [markdown]
# ## Conclusiones Finales
#
# Los resultados de este análisis revelan diferencias claras y significativas entre los operadores eficaces e ineficaces en cuanto a llamadas perdidas, tiempos de espera y duración de las llamadas. Estos hallazgos corroboran la clasificación de los operadores, apoyando el análisis en curso de aquellos con menor eficacia.
#
# ### Clasificación y Oportunidades de Mejora
#
# Al agrupar a los operadores en dos categorías—eficaces e ineficaces—se observa una disparidad notable en el número de operadores en cada grupo: 7,313 en la categoría de ineficaces frente a 36,074 en la de eficaces. Sin embargo, al aplicar criterios más estrictos para definir la ineptitud, como un número de llamadas salientes menor a 50, más de 50 llamadas perdidas, y un tiempo de espera superior a 175 segundos, se concluye que más del 90% de los operadores podrían clasificarse como ineficaces. Esta cifra sugiere la necesidad de una reunión con supervisores, gerentes y personal calificado para revisar y ajustar los umbrales y las métricas de desempeño objetivo. Esto es crucial, ya que, aunque muchos operadores no superen todos los límites establecidos, cada uno podría tener al menos un área de oportunidad para mejorar su desempeño.
#
# ### Análisis por Clusters
#
# El análisis realizado al clasificar los operadores en clusters, junto con las métricas clave, permite identificar relaciones entre estas métricas y el desempeño de los operadores. Por ejemplo, los operadores altamente eficaces y eficaces presentan tiempos de espera relativamente bajos en comparación con los moderadamente eficaces. Además, se destaca la relación entre la duración de las llamadas y el tiempo de espera, donde la diferencia más notable se observa entre los operadores altamente eficaces y aquellos de desempeño promedio.
#
# Por otro lado, los operadores catalogados como ineficaces o moderadamente ineficaces presentan una actividad mínima, sugiriendo que no están tomando llamadas de manera efectiva, lo que genera costos innecesarios para la organización.
#
# ### Análisis Estadístico
#
# El análisis estadístico realizado mediante la prueba de Mann-Whitney U proporciona evidencia robusta sobre las diferencias entre los grupos:
#
# - **Estadístico de Mann-Whitney U = 0** y **valor p = 0.0** indican una diferencia altamente significativa en la tasa de llamadas perdidas entre los operadores eficaces e ineficaces. Un estadístico U de 0 sugiere que no hay solapamiento en las distribuciones de ambos grupos, evidenciando que su desempeño es completamente distinto en esta métrica.
#
# - En cuanto a la duración de las llamadas, un **estadístico U = 236,062,364.0** junto con un **valor p = 0.0** también refleja una diferencia estadísticamente significativa entre los dos grupos. Esto indica que la duración promedio de las llamadas varía considerablemente entre los operadores eficaces e ineficaces.
#
# ### Implicaciones para la Gestión
#
# Estos resultados no solo confirman que los operadores ineficaces tienen una tasa de llamadas perdidas más alta en comparación con sus contrapartes eficaces, sino que también sugieren la posibilidad de implementar medidas de mejora específicas. El seguimiento de la duración de las llamadas puede ofrecer información adicional sobre las razones detrás de la ineptitud y permitir la identificación de áreas de capacitación o ajuste de procesos.
#
# ### Recomendaciones para CallMeMaybe
#
# 1. **Revisión de Umbrales**: Organizar una reunión con supervisores y gerentes para revisar y posiblemente redefinir los umbrales utilizados para clasificar a los operadores como eficaces o ineficaces. Establecer métricas que reflejen más adecuadamente el desempeño esperado.
#
# 2. **Capacitación Personalizada**: Implementar programas de capacitación dirigidos a los operadores catalogados como ineficaces, enfocándose en habilidades específicas que aborden sus áreas de mejora identificadas, como gestión del tiempo de espera y técnicas de cierre de llamadas.
#
# 3. **Monitoreo Continuo**: Establecer un sistema de monitoreo continuo para evaluar el desempeño de los operadores en tiempo real, lo que permitirá realizar ajustes proactivos en lugar de reacciones posteriores a los problemas.
#
# 4. **Reuniones de Feedback**: Fomentar reuniones regulares de retroalimentación en las que los operadores puedan compartir experiencias y desafíos, creando un ambiente de colaboración y aprendizaje.
#
# 5. **Análisis Regular**: Realizar análisis periódicos utilizando las métricas identificadas en este estudio para asegurar que las intervenciones implementadas están teniendo el efecto deseado y que los operadores están mejorando su desempeño.
#
# Implementando estas recomendaciones, CallMeMaybe no solo podrá mejorar el rendimiento de sus operadores, sino también optimizar la satisfacción del cliente y reducir costos operativos innecesarios.

# %% [markdown]
# <div class="alert alert-block alert-danger"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>A resolver</b> ❗ - En esta sección faltan conclusiones finales. Para completar el análisis y ofrecer un cierre efectivo, es fundamental agregar una sección de conclusiones que resuma los hallazgos clave, reflexione sobre el impacto de estos resultados en la eficiencia de los operadores y sugiera acciones futuras basadas en el análisis. Esto brindará claridad sobre los resultados y fortalecerá la comprensión del proyecto.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# <b>Atención</b> ⚠️ - Para mejorar la claridad y profundidad de tus conclusiones finales, considera las siguientes pautas:
#
# <ul>
#     <li><b>Resumen de los Hallazgos Clave:</b> Incluye brevemente tus descubrimientos más importantes.</li>
#     <li><b>Impacto de tus Elecciones de Procesamiento de Datos:</b> Reflexiona sobre cómo tus decisiones influyeron en los resultados.</li>
#     <li><b>Relación con los Objetivos Iniciales:</b> Vincula tus hallazgos con los objetivos del proyecto.</li>
#     <li><b>Relevancia de los Hallazgos:</b> Discute la importancia de tus resultados para la empresa o usuarios.</li>
#     <li><b>Sugerencias y Recomendaciones:</b> Ofrece cualquier consejo basado en tus análisis.</li>
#     <li><b>Reflexiones Finales:</b> Concluye con tus pensamientos finales y aprendizajes del proyecto.</li>
# </ul>
#
# Recuerda que una conclusión efectiva resume tus hallazgos y proporciona insights y reflexiones sobre su impacto y relevancia. ¡Sigue así y éxito en la etapa final!
# </div>

# %% [markdown]
# ## Referencias
#
# ### 1. **Análisis Exploratorio de Datos (Exploratory Data Analysis - EDA)**:
#    - **Libro**: *Python for Data Analysis* por Wes McKinney.
#      - Este libro cubre las técnicas esenciales de análisis de datos en Python utilizando bibliotecas como `pandas`, `numpy` y `matplotlib`. También es una excelente referencia para comprender cómo realizar análisis exploratorio de datos.
#      - **Referencia**: McKinney, W. (2017). *Python for Data Analysis: Data Wrangling with Pandas, NumPy, and IPython*. O'Reilly Media.
#
#    - **Artículo**: *A Comprehensive Guide to Data Exploration in Python* en Towards Data Science.
#      - Este artículo ofrece una guía completa sobre el análisis exploratorio de datos, incluyendo gráficos, histogramas y análisis estadísticos.
#      - **Referencia**: [A Comprehensive Guide to Data Exploration in Python](https://towardsdatascience.com/a-comprehensive-guide-to-exploratory-data-analysis-26c10e80b2c0)
#
# ### 2. **Segmentación por Clustering usando K-means**:
#    - **Libro**: *Data Science from Scratch: First Principles with Python* por Joel Grus.
#      - Este libro es útil para comprender los fundamentos de los algoritmos de machine learning, incluyendo el clustering con K-means.
#      - **Referencia**: Grus, J. (2019). *Data Science from Scratch: First Principles with Python*. O'Reilly Media.
#
#    - **Artículo**: *Clustering Algorithms: A Comparative Study* en *International Journal of Advanced Research in Artificial Intelligence*.
#      - Este estudio compara diferentes algoritmos de clustering, incluido K-means, y analiza sus ventajas y desventajas.
#      - **Referencia**: Jain, A.K., Murty, M.N., & Flynn, P.J. (1999). *Data Clustering: A Review*. ACM Computing Surveys, 31(3), 264-323.
#
# ### 3. **Pruebas de Hipótesis en Python**:
#    - **Libro**: *Statistics for Data Science* por James D. Miller.
#      - Este libro proporciona una visión general de cómo aplicar pruebas estadísticas, como la prueba t y ANOVA, en Python.
#      - **Referencia**: Miller, J.D. (2017). *Statistics for Data Science*. Packt Publishing.
#
#    - **Artículo**: *Hypothesis Testing in Python* en Real Python.
#      - Un artículo detallado sobre cómo llevar a cabo pruebas de hipótesis en Python utilizando `scipy.stats` para realizar pruebas t y ANOVA.
#      - **Referencia**: [Hypothesis Testing in Python](https://realpython.com/python-hypothesis-testing/)
#
# ### 4. **Tableau para la Visualización de Datos**:
#    - **Libro**: *Communicating Data with Tableau* por Ben Jones.
#      - Este libro te guiará a través de las mejores prácticas para usar Tableau para comunicar datos y crear visualizaciones eficaces.
#      - **Referencia**: Jones, B. (2014). *Communicating Data with Tableau*. O'Reilly Media.
#
#    - **Artículo**: *An Introduction to Tableau for Data Science* en DataCamp.
#      - Una introducción al uso de Tableau para la visualización de datos, incluyendo ejemplos sobre cómo integrar datos desde Python y crear gráficos interactivos.
#      - **Referencia**: [Introduction to Tableau for Data Science](https://www.datacamp.com/community/tutorials/tableau-tutorial)
#
# ### 5. **Evaluación de Eficiencia de Operadores**:
#    - **Artículo**: *Call Center Analytics: The Key Metrics That Matter* en *Harvard Business Review*.
#      - Un artículo sobre las métricas clave para medir la eficiencia de operadores en un centro de llamadas, que puede ser útil para contextualizar tu análisis.
#      - **Referencia**: [Call Center Analytics: The Key Metrics That Matter](https://hbr.org/2017/02/call-center-analytics-the-key-metrics-that-matter)
#
# Estos recursos ofrecen una visión integral sobre los temas clave que hemos discutido: análisis exploratorio de datos, clustering, pruebas de hipótesis y la visualización en Tableau. Si necesitas más detalles o acceso a recursos específicos, estaré encantado de ayudarte a encontrar más fuentes.

# %% [markdown]
# # Comentarios del Revisor

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Has realizado un trabajo excelente en la implementación de este proyecto, demostrando un sólido análisis y un dominio destacado en técnicas de segmentación y evaluación de eficiencia de operadores. **Sin embargo, el proyecto aún no puede aprobars** ya que falta una sección de **conclusiones**. Esta sección es fundamental para sintetizar los hallazgos clave y proporcionar recomendaciones o insights derivados de tu análisis, lo cual fortalecerá tu proyecto y facilitará la comprensión de los resultados.
#
# Tu proyecto refleja un buen manejo en el análisis exploratorio, identificación de operadores ineficaces y uso de técnicas de clustering para segmentar la eficiencia operativa. También has aplicado herramientas estadísticas avanzadas, lo cual es excelente para un análisis integral de los datos.
#
# **Puntos Positivos:**
# - **Limpieza de datos:** La estructura y limpieza de datos están bien logradas, incluyendo la incorporación de columnas clave como la tasa de llamadas perdidas, que aporta claridad al análisis.
# - **Implementación de clustering:** La segmentación de operadores mediante K-means evidencia un entendimiento avanzado de técnicas de aprendizaje no supervisado y aporta insights relevantes.
# - **Visualización de resultados:** Las gráficas y el uso del método del codo están bien ejecutados, facilitando la identificación de un número óptimo de clústeres.
#
# **Áreas para Seguir Investigando:**
# - **Conclusiones:** Incluir una sección final de conclusiones ayudará a consolidar tus hallazgos y proporcionar recomendaciones informadas basadas en el análisis.
# - **Validación de supuestos en pruebas estadísticas:** Se recomienda validar los supuestos de normalidad y homogeneidad antes de realizar pruebas t y ANOVA para asegurar que los resultados sean precisos y apropiados.
# - **Documentación y README:** Completar el README en el repositorio brindará una guía clara para aquellos que deseen entender y replicar el análisis.
#
# En general, has hecho un trabajo excelente. Continúa mejorando en la estructuración y validación de tus análisis. ¡Vas por muy buen camino! 🚀💪😊
#
# </div>
